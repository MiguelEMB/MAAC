# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Fetch data
df = yf.download('AAPL', start='2010-01-01', end='2023-06-29')

# Scale the data with MinMaxScaler
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns, index=df.index)
from joblib import dump, load

# Save the scaler
dump(scaler, 'scaler.joblib') 

# Load the scaler
scaler = load('scaler.joblib') 

# Add a column for previous day's close price
df_scaled['Prev_Close'] = df_scaled['Close'].shift(1)

# Drop the first row, which will contain NaN because of the shift operation
df_scaled = df_scaled.dropna()

# Separate features (X) and target (y)
X = df_scaled.drop('Close', axis=1)
y = df_scaled['Close']

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=42)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(X)
# Out:
#                 Open      High       Low  Adj Close    Volume  Prev_Close
# Date
# 2010-01-05  0.004385  0.003825  0.004543   0.003695  0.307026    0.004300
# 2010-01-06  0.004342  0.003755  0.004049   0.003131  0.280076    0.004372
# 2010-01-07  0.003823  0.003124  0.003714   0.003067  0.239427    0.003705
# 2010-01-08  0.003537  0.003124  0.003716   0.003298  0.223434    0.003628
# 2010-01-11  0.004030  0.003320  0.003595   0.002989  0.231354    0.003903
# ...              ...       ...       ...        ...       ...         ...
# 2023-06-22  0.976859  0.984418  0.978264   0.987733  0.008695    0.970996
# 2023-06-23  0.986855  0.987206  0.985675   0.985988  0.009689    0.987664
# 2023-06-26  0.993925  0.989885  0.986892   0.978301  0.006985    0.985909
# 2023-06-27  0.988733  0.991744  0.989325   0.993512  0.008416    0.978179
# 2023-06-28  1.000000  1.000000  1.000000   1.000000  0.008680    0.993476
#
# [3393 rows x 6 columns]

# %%
# Define the lookback period
lookback = 60

# Reshape to (samples, time_steps, features)
X_train_reshaped = np.array([X_train.values[i-lookback:i, :] for i in range(lookback, len(X_train))])
y_train_reshaped = y_train[lookback:]

X_test_reshaped = np.array([X_test.values[i-lookback:i, :] for i in range(lookback, len(X_test))])
y_test_reshaped = y_test[lookback:]

# %%
# Choose the split point, let's say we'll use 95% of the data for training
split_point = int(len(df_scaled) * 0.95)

# Split into train and test sets
X_train = X[:split_point]
X_test = X[split_point:]
y_train = y[:split_point]
y_test = y[split_point:]

# %%
# Let's say X_train is of shape (1000, 10, 2)
# Here, we have 1000 samples, sequence length of 10 and 2 features
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.optimizers import RMSprop
from keras.regularizers import l1
from keras.callbacks import EarlyStopping
from keras.layers import LSTM

# Your LSTM model
nn = Sequential()
nn.add(LSTM(128, input_shape=(60, 6), kernel_initializer='normal', activation='tanh', return_sequences=True))  # Adjusted input shape
nn.add(BatchNormalization())
nn.add(Dropout(0.3))
nn.add(LSTM(64, kernel_initializer='normal', activation='tanh', kernel_regularizer=l1(0.001), return_sequences=False))
nn.add(BatchNormalization())
nn.add(Dropout(0.3))
nn.add(Dense(32, kernel_initializer='normal', activation='relu', kernel_regularizer=l1(0.001)))
nn.add(Dense(1, kernel_initializer='normal'))

# And y_train should be of shape (1000, )
# As we are predicting a single value based on each sequence

# %%
# Compile the model
nn.compile(loss='mean_absolute_error', optimizer=RMSprop(learning_rate=0.0001))

# Define EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=30, verbose=1)

# Train the model
history = nn.fit(
    X_train_reshaped, 
    y_train_reshaped, 
    epochs=200, 
    batch_size=32, 
    validation_split=0.2,  # here we're holding out 20% of the training data for validation
    callbacks=[early_stopping]
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RMSprop` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RMSprop`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.RMSprop`.
# Epoch 1/200
# 80/80 [==============================] - 7s 68ms/step - loss: 1.4986 - val_loss: 1.4377
# Epoch 2/200
# 80/80 [==============================] - 5s 64ms/step - loss: 1.2829 - val_loss: 1.2426
# Epoch 3/200
# 80/80 [==============================] - 5s 63ms/step - loss: 1.1071 - val_loss: 1.0711
# Epoch 4/200
# 80/80 [==============================] - 5s 63ms/step - loss: 0.9573 - val_loss: 0.9202
# Epoch 5/200
# 80/80 [==============================] - 6s 73ms/step - loss: 0.8278 - val_loss: 0.7889
# Epoch 6/200
# 80/80 [==============================] - 5s 67ms/step - loss: 0.7198 - val_loss: 0.6842
# Epoch 7/200
# 80/80 [==============================] - 6s 70ms/step - loss: 0.6270 - val_loss: 0.5985
# Epoch 8/200
# 80/80 [==============================] - 5s 61ms/step - loss: 0.5527 - val_loss: 0.5309
# Epoch 9/200
# 80/80 [==============================] - 5s 60ms/step - loss: 0.4912 - val_loss: 0.4784
# Epoch 10/200
# 80/80 [==============================] - 5s 60ms/step - loss: 0.4419 - val_loss: 0.4337
# Epoch 11/200
# 80/80 [==============================] - 5s 61ms/step - loss: 0.4038 - val_loss: 0.4048
# Epoch 12/200
# 80/80 [==============================] - 5s 66ms/step - loss: 0.3722 - val_loss: 0.3735
# Epoch 13/200
# 80/80 [==============================] - 5s 66ms/step - loss: 0.3495 - val_loss: 0.3509
# Epoch 14/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.3292 - val_loss: 0.3363
# Epoch 15/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.3148 - val_loss: 0.3212
# Epoch 16/200
# 80/80 [==============================] - 6s 70ms/step - loss: 0.3000 - val_loss: 0.3094
# Epoch 17/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.2910 - val_loss: 0.3013
# Epoch 18/200
# 80/80 [==============================] - 5s 69ms/step - loss: 0.2810 - val_loss: 0.2913
# Epoch 19/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.2736 - val_loss: 0.2862
# Epoch 20/200
# 80/80 [==============================] - 5s 68ms/step - loss: 0.2684 - val_loss: 0.2804
# Epoch 21/200
# 80/80 [==============================] - 5s 59ms/step - loss: 0.2619 - val_loss: 0.2741
# Epoch 22/200
# 80/80 [==============================] - 5s 58ms/step - loss: 0.2584 - val_loss: 0.2691
# Epoch 23/200
# 80/80 [==============================] - 5s 58ms/step - loss: 0.2532 - val_loss: 0.2665
# Epoch 24/200
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2491 - val_loss: 0.2624
# Epoch 25/200
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2459 - val_loss: 0.2624
# Epoch 26/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.2429 - val_loss: 0.2566
# Epoch 27/200
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2404 - val_loss: 0.2539
# Epoch 28/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.2370 - val_loss: 0.2497
# Epoch 29/200
# 80/80 [==============================] - 5s 61ms/step - loss: 0.2352 - val_loss: 0.2483
# Epoch 30/200
# 80/80 [==============================] - 5s 59ms/step - loss: 0.2330 - val_loss: 0.2457
# Epoch 31/200
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2309 - val_loss: 0.2453
# Epoch 32/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.2283 - val_loss: 0.2412
# Epoch 33/200
# 80/80 [==============================] - 5s 58ms/step - loss: 0.2263 - val_loss: 0.2393
# Epoch 34/200
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2248 - val_loss: 0.2404
# Epoch 35/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.2234 - val_loss: 0.2376
# Epoch 36/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.2214 - val_loss: 0.2344
# Epoch 37/200
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2203 - val_loss: 0.2344
# Epoch 38/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.2189 - val_loss: 0.2324
# Epoch 39/200
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2177 - val_loss: 0.2320
# Epoch 40/200
# 80/80 [==============================] - 5s 56ms/step - loss: 0.2165 - val_loss: 0.2384
# Epoch 41/200
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2155 - val_loss: 0.2312
# Epoch 42/200
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2142 - val_loss: 0.2352
# Epoch 43/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2137 - val_loss: 0.2277
# Epoch 44/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.2128 - val_loss: 0.2257
# Epoch 45/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.2113 - val_loss: 0.2252
# Epoch 46/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.2101 - val_loss: 0.2240
# Epoch 47/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.2089 - val_loss: 0.2251
# Epoch 48/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2088 - val_loss: 0.2235
# Epoch 49/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.2077 - val_loss: 0.2218
# Epoch 50/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2070 - val_loss: 0.2221
# Epoch 51/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.2065 - val_loss: 0.2208
# Epoch 52/200
# 80/80 [==============================] - 5s 59ms/step - loss: 0.2058 - val_loss: 0.2238
# Epoch 53/200
# 80/80 [==============================] - 5s 62ms/step - loss: 0.2054 - val_loss: 0.2194
# Epoch 54/200
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2050 - val_loss: 0.2187
# Epoch 55/200
# 80/80 [==============================] - 5s 60ms/step - loss: 0.2046 - val_loss: 0.2188
# Epoch 56/200
# 80/80 [==============================] - 5s 59ms/step - loss: 0.2038 - val_loss: 0.2183
# Epoch 57/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.2038 - val_loss: 0.2187
# Epoch 58/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2030 - val_loss: 0.2180
# Epoch 59/200
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2028 - val_loss: 0.2168
# Epoch 60/200
# 80/80 [==============================] - 5s 58ms/step - loss: 0.2020 - val_loss: 0.2167
# Epoch 61/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.2019 - val_loss: 0.2159
# Epoch 62/200
# 80/80 [==============================] - 5s 59ms/step - loss: 0.2014 - val_loss: 0.2164
# Epoch 63/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.2012 - val_loss: 0.2152
# Epoch 64/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.2007 - val_loss: 0.2159
# Epoch 65/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.2005 - val_loss: 0.2154
# Epoch 66/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.2003 - val_loss: 0.2156
# Epoch 67/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1999 - val_loss: 0.2149
# Epoch 68/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1996 - val_loss: 0.2143
# Epoch 69/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1997 - val_loss: 0.2151
# Epoch 70/200
# 80/80 [==============================] - 5s 64ms/step - loss: 0.1992 - val_loss: 0.2141
# Epoch 71/200
# 80/80 [==============================] - 5s 60ms/step - loss: 0.1991 - val_loss: 0.2132
# Epoch 72/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1989 - val_loss: 0.2141
# Epoch 73/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1986 - val_loss: 0.2129
# Epoch 74/200
# 80/80 [==============================] - 4s 52ms/step - loss: 0.1985 - val_loss: 0.2141
# Epoch 75/200
# 80/80 [==============================] - 4s 52ms/step - loss: 0.1985 - val_loss: 0.2162
# Epoch 76/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1983 - val_loss: 0.2125
# Epoch 77/200
# 80/80 [==============================] - 4s 52ms/step - loss: 0.1981 - val_loss: 0.2126
# Epoch 78/200
# 80/80 [==============================] - 5s 60ms/step - loss: 0.1980 - val_loss: 0.2121
# Epoch 79/200
# 80/80 [==============================] - 5s 58ms/step - loss: 0.1978 - val_loss: 0.2127
# Epoch 80/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1977 - val_loss: 0.2126
# Epoch 81/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1979 - val_loss: 0.2133
# Epoch 82/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1976 - val_loss: 0.2121
# Epoch 83/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1975 - val_loss: 0.2123
# Epoch 84/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1973 - val_loss: 0.2139
# Epoch 85/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1973 - val_loss: 0.2115
# Epoch 86/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1972 - val_loss: 0.2118
# Epoch 87/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1972 - val_loss: 0.2119
# Epoch 88/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1971 - val_loss: 0.2114
# Epoch 89/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1970 - val_loss: 0.2114
# Epoch 90/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1969 - val_loss: 0.2127
# Epoch 91/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1971 - val_loss: 0.2116
# Epoch 92/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1969 - val_loss: 0.2116
# Epoch 93/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1968 - val_loss: 0.2121
# Epoch 94/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1967 - val_loss: 0.2110
# Epoch 95/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1967 - val_loss: 0.2108
# Epoch 96/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1966 - val_loss: 0.2109
# Epoch 97/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1967 - val_loss: 0.2109
# Epoch 98/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1966 - val_loss: 0.2170
# Epoch 99/200
# 80/80 [==============================] - 5s 56ms/step - loss: 0.1966 - val_loss: 0.2105
# Epoch 100/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1964 - val_loss: 0.2129
# Epoch 101/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1966 - val_loss: 0.2113
# Epoch 102/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1963 - val_loss: 0.2115
# Epoch 103/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1965 - val_loss: 0.2123
# Epoch 104/200
# 80/80 [==============================] - 5s 56ms/step - loss: 0.1965 - val_loss: 0.2134
# Epoch 105/200
# 80/80 [==============================] - 5s 57ms/step - loss: 0.1966 - val_loss: 0.2109
# Epoch 106/200
# 80/80 [==============================] - 5s 60ms/step - loss: 0.1960 - val_loss: 0.2553
# Epoch 107/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1967 - val_loss: 0.2107
# Epoch 108/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1964 - val_loss: 0.2345
# Epoch 109/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1965 - val_loss: 0.2113
# Epoch 110/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1963 - val_loss: 0.2113
# Epoch 111/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1963 - val_loss: 0.2102
# Epoch 112/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1963 - val_loss: 0.2107
# Epoch 113/200
# 80/80 [==============================] - 4s 52ms/step - loss: 0.1964 - val_loss: 0.2113
# Epoch 114/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1964 - val_loss: 0.2113
# Epoch 115/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1962 - val_loss: 0.2205
# Epoch 116/200
# 80/80 [==============================] - 5s 56ms/step - loss: 0.1963 - val_loss: 0.2110
# Epoch 117/200
# 80/80 [==============================] - 5s 56ms/step - loss: 0.1963 - val_loss: 0.2113
# Epoch 118/200
# 80/80 [==============================] - 5s 56ms/step - loss: 0.1963 - val_loss: 0.2104
# Epoch 119/200
# 80/80 [==============================] - 5s 58ms/step - loss: 0.1961 - val_loss: 0.2105
# Epoch 120/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1962 - val_loss: 0.2132
# Epoch 121/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1965 - val_loss: 0.2104
# Epoch 122/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1963 - val_loss: 0.2108
# Epoch 123/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1962 - val_loss: 0.2110
# Epoch 124/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1963 - val_loss: 0.2108
# Epoch 125/200
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1961 - val_loss: 0.2105
# Epoch 126/200
# 80/80 [==============================] - 5s 58ms/step - loss: 0.1962 - val_loss: 0.2377
# Epoch 127/200
# 80/80 [==============================] - 5s 58ms/step - loss: 0.1963 - val_loss: 0.2110
# Epoch 128/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1961 - val_loss: 0.2114
# Epoch 129/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1960 - val_loss: 0.2234
# Epoch 130/200
# 80/80 [==============================] - 5s 58ms/step - loss: 0.1963 - val_loss: 0.2110
# Epoch 131/200
# 80/80 [==============================] - 4s 52ms/step - loss: 0.1963 - val_loss: 0.2125
# Epoch 132/200
# 80/80 [==============================] - 4s 53ms/step - loss: 0.1962 - val_loss: 0.2139
# Epoch 133/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1960 - val_loss: 0.2187
# Epoch 134/200
# 80/80 [==============================] - 5s 56ms/step - loss: 0.1964 - val_loss: 0.2107
# Epoch 135/200
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1963 - val_loss: 0.2105
# Epoch 136/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1962 - val_loss: 0.2110
# Epoch 137/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1962 - val_loss: 0.2110
# Epoch 138/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1960 - val_loss: 0.2106
# Epoch 139/200
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1964 - val_loss: 0.2111
# Epoch 140/200
# 80/80 [==============================] - 5s 56ms/step - loss: 0.1964 - val_loss: 0.2121
# Epoch 141/200
# 80/80 [==============================] - 5s 57ms/step - loss: 0.1963 - val_loss: 0.2103
# Epoch 141: early stopping

# %%
# Evaluate the model on the test data
test_loss = nn.evaluate(X_test_reshaped, y_test_reshaped)

print(f'Test loss: {test_loss}')
# Out:
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1883
# Test loss: 0.18829162418842316

# %%
# Get the latest 60 days' data
latest_data = df_scaled[-60:]

# Reshape the data to match the input shape of the model
latest_data_reshaped = np.array([latest_data.values])

# Scale the data
latest_data_scaled = scaler.transform(latest_data_reshaped.reshape(-1, 6))

# Reshape the data back to (samples, time_steps, features)
latest_data_reshaped = latest_data_scaled.reshape(latest_data_scaled.shape[0], 60, 6)

# Predict for the next 7 days
predictions = []
for _ in range(7):
    # Predict the next day's closing price
    prediction = nn.predict(latest_data_reshaped)
    
    # Append the prediction to the list
    predictions.append(prediction[0][0])
    
    # Shift the data to the next day by removing the first row and appending the predicted value
    latest_data_reshaped = np.concatenate([latest_data_reshaped[:, 1:, :], [[prediction[0]]]])

# Invert scaling on predictions
predictions = scaler.inverse_transform([[x] for x in predictions])

# Print the predictions for the next 7 days
for i in range(len(predictions)):
      print(f"Day {i+1}: Predicted Close Price: {predictions[i][0]:.2f}")
# Out:
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 11
#       8 latest_data_scaled = scaler.transform(latest_data_reshaped.reshape(-1, 6))
#      10 # Reshape the data back to (samples, time_steps, features)
# ---> 11 latest_data_reshaped = latest_data_scaled.reshape(latest_data_scaled.shape[0], 60, 6)
#      13 # Predict for the next 7 days
#      14 predictions = []
#
# ValueError: cannot reshape array of size 420 into shape (70,60,6)
