# %%
import numpy as np
import pandas as pd
import yfinance as yf
import plotly.graph_objs as go


data = yf.download(tickers='BTC-USD',period = '8d', interval = '90m')

data['MA5'] = data['Close'].rolling(5).mean()
data['MA20'] = data['Close'].rolling(20).mean()


fig = go.Figure()


fig.add_trace(go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name = 'market data'))

#Add Moving average on the graph
fig.add_trace(go.Scatter(x=data.index, y= data['MA20'],line=dict(color='blue', width=1.5), name = 'Long Term MA'))
fig.add_trace(go.Scatter(x=data.index, y= data['MA5'],line=dict(color='orange', width=1.5), name = 'Short Term MA'))

#Updating X axis and graph
# X-Axes
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=3, label="3d", step="days", stepmode="backward"),
            dict(count=5, label="5d", step="days", stepmode="backward"),
            dict(count=7, label="WTD", step="days", stepmode="todate"),
            dict(step="all")
        ])
    )
)

#Show
fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 32
#      28 fig.add_trace(go.Scatter(x=data.index, y= data['MA5'],line=dict(color='orange', width=1.5), name = 'Short Term MA'))
#      30 #Updating X axis and graph
#      31 # X-Axes
# ---> 32 fig.update_xaxes(
#      33     rangeslider_visible=True,
#      34     rangeselector=dict(
#      35         buttons=list([
#      36             dict(count=3, label="3d", step="days", stepmode="backward"),
#      37             dict(count=5, label="5d", step="days", stepmode="backward"),
#      38             dict(count=7, label="WTD", step="days", stepmode="todate"),
#      39             dict(step="all")
#      40         ])
#      41     )
#      42 )
#      44 #Show
#      45 fig.show()
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/plotly/graph_objs/_figure.py:22252, in Figure.update_xaxes(self, patch, selector, overwrite, row, col, **kwargs)
#   22213 """
#   22214 Perform a property update operation on all xaxis objects
#   22215 that satisfy the specified selection criteria
#    (...)
#   22249     Returns the Figure object that the method was called on
#   22250 """
#   22251 for obj in self.select_xaxes(selector=selector, row=row, col=col):
# > 22252     obj.update(patch, overwrite=overwrite, **kwargs)
#   22254 return self
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/plotly/basedatatypes.py:5136, in BasePlotlyType.update(self, dict1, overwrite, **kwargs)
#    5134     with self.figure.batch_update():
#    5135         BaseFigure._perform_update(self, dict1, overwrite=overwrite)
# -> 5136         BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    5137 else:
#    5138     BaseFigure._perform_update(self, dict1, overwrite=overwrite)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/plotly/basedatatypes.py:3918, in BaseFigure._perform_update(plotly_obj, update_obj, overwrite)
#    3912 validator = plotly_obj._get_prop_validator(key)
#    3914 if isinstance(validator, CompoundValidator) and isinstance(val, dict):
#    3915
#    3916     # Update compound objects recursively
#    3917     # plotly_obj[key].update(val)
# -> 3918     BaseFigure._perform_update(plotly_obj[key], val)
#    3919 elif isinstance(validator, CompoundArrayValidator):
#    3920     if plotly_obj[key]:
#    3921         # plotly_obj has an existing non-empty array for key
#    3922         # In this case we merge val into the existing elements
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/plotly/basedatatypes.py:3936, in BaseFigure._perform_update(plotly_obj, update_obj, overwrite)
#    3930             plotly_obj[key] = plotly_obj[key] + tuple(
#    3931                 val[len(plotly_obj[key]) :]
#    3932             )
#    3933     else:
#    3934         # plotly_obj is an empty or uninitialized list for key
#    3935         # In this case we accept val as is
# -> 3936         plotly_obj[key] = val
#    3937 else:
#    3938     # Assign non-compound value
#    3939     plotly_obj[key] = val
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/plotly/basedatatypes.py:4869, in BasePlotlyType.__setitem__(self, prop, value)
#    4867 # ### Handle compound array property ###
#    4868 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
# -> 4869     self._set_array_prop(prop, value)
#    4871 # ### Handle simple property ###
#    4872 else:
#    4873     self._set_prop(prop, value)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/plotly/basedatatypes.py:5350, in BasePlotlyType._set_array_prop(self, prop, val)
#    5347 # Import value
#    5348 # ------------
#    5349 validator = self._get_validator(prop)
# -> 5350 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5352 # Save deep copies of current and new states
#    5353 # ------------------------------------------
#    5354 curr_val = self._compound_array_props.get(prop, None)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:2567, in CompoundArrayValidator.validate_coerce(self, v, skip_invalid)
#    2565     res.append(self.data_class(v_el))
#    2566 elif isinstance(v_el, dict):
# -> 2567     res.append(self.data_class(v_el, skip_invalid=skip_invalid))
#    2568 else:
#    2569     if skip_invalid:
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/plotly/graph_objs/layout/xaxis/rangeselector/_button.py:350, in Button.__init__(self, arg, count, label, name, step, stepmode, templateitemname, visible, **kwargs)
#     348 _v = step if step is not None else _v
#     349 if _v is not None:
# --> 350     self["step"] = _v
#     351 _v = arg.pop("stepmode", None)
#     352 _v = stepmode if stepmode is not None else _v
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/plotly/basedatatypes.py:4873, in BasePlotlyType.__setitem__(self, prop, value)
#    4869         self._set_array_prop(prop, value)
#    4871     # ### Handle simple property ###
#    4872     else:
# -> 4873         self._set_prop(prop, value)
#    4874 else:
#    4875     # Make sure properties dict is initialized
#    4876     self._init_props()
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/plotly/basedatatypes.py:5217, in BasePlotlyType._set_prop(self, prop, val)
#    5215         return
#    5216     else:
# -> 5217         raise err
#    5219 # val is None
#    5220 # -----------
#    5221 if val is None:
#    5222     # Check if we should send null update
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/plotly/basedatatypes.py:5212, in BasePlotlyType._set_prop(self, prop, val)
#    5209 validator = self._get_validator(prop)
#    5211 try:
# -> 5212     val = validator.validate_coerce(val)
#    5213 except ValueError as err:
#    5214     if self._skip_invalid:
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:610, in EnumeratedValidator.validate_coerce(self, v)
#     608     v = self.perform_replacemenet(v)
#     609     if not self.in_values(v):
# --> 610         self.raise_invalid_val(v)
#     611 return v
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:287, in BaseValidator.raise_invalid_val(self, v, inds)
#     284             for i in inds:
#     285                 name += "[" + str(i) + "]"
# --> 287         raise ValueError(
#     288             """
#     289     Invalid value of type {typ} received for the '{name}' property of {pname}
#     290         Received value: {v}
#     291
#     292 {valid_clr_desc}""".format(
#     293                 name=name,
#     294                 pname=self.parent_name,
#     295                 typ=type_str(v),
#     296                 v=repr(v),
#     297                 valid_clr_desc=self.description(),
#     298             )
#     299         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'step' property of layout.xaxis.rangeselector.button
#         Received value: 'days'
#
#     The 'step' property is an enumeration that may be specified as:
#       - One of the following enumeration values:
#             ['month', 'year', 'day', 'hour', 'minute', 'second',
#             'all']
