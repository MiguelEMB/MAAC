# %%
import yfinance as yf
import pandas as pd

def calculate_pivot_points(high, low, close):
    pivot = (high + low + close) / 3
    support1 = (2 * pivot) - high
    resistance1 = (2 * pivot) - low
    support2 = pivot - (high - low)
    resistance2 = pivot + (high - low)
    support3 = pivot - (2 * (high - low))
    resistance3 = pivot + (2 * (high - low))
    
    data = {
        "Pivot Point": pivot,
        "Support 1": support1,
        "Support 2": support2,
        "Support 3": support3,
        "Resistance 1": resistance1,
        "Resistance 2": resistance2,
        "Resistance 3": resistance3
    }
    
    return pd.DataFrame(data, index=["Latest"])

# Ticker symbol of the stock
ticker_symbol = "AAPL"

# Retrieve historical stock data from Yahoo Finance
stock_data = yf.download(ticker_symbol, start="2023-01-01", end="2023-06-30")

# Extract high, low, and close prices from the stock data
high_prices = stock_data["High"]
low_prices = stock_data["Low"]
close_prices = stock_data["Close"]

# Calculate pivot points for the latest day
latest_high = high_prices[-1]
latest_low = low_prices[-1]
latest_close = close_prices[-1]

pivot_points_df = calculate_pivot_points(latest_high, latest_low, latest_close)

pivot_points_df.head()

# %%
import pandas as pd

def calculate_buy_sell_volume(ticker):
    # Assuming you have the necessary market data, fetch the volume data for the ticker
    # Replace the following lines with your code to fetch the volume data
    volume_data = {
        'timestamp': ['2023-07-01', '2023-07-02', '2023-07-03', '2023-07-04', '2023-07-05'],
        'volume': [10000, 15000, 8000, 12000, 20000],
        'is_buy': [True, True, False, True, False]
    }
    
    # Create a DataFrame from the volume data
    df = pd.DataFrame(volume_data)
    
    # Group the data by 'is_buy' column and calculate the sum of volume for each group
    volume_summary = df.groupby('is_buy')['volume'].sum().reset_index()
    
    # Create a new DataFrame to store the buy and sell volume
    volume_df = pd.DataFrame(columns=['Buy Volume', 'Sell Volume'])
    volume_df.loc[0] = [0, 0]
    
    # Extract the buy and sell volume from the summary and store in the DataFrame
    for _, row in volume_summary.iterrows():
        if row['is_buy']:
            volume_df.loc[0, 'Buy Volume'] = row['volume']
        else:
            volume_df.loc[0, 'Sell Volume'] = row['volume']
    
    return volume_df

# Example usage
ticker_symbol = 'XYZ'  # Replace with your desired ticker symbol
volume_dataframe = calculate_buy_sell_volume(ticker_symbol)
print(volume_dataframe)

# %%
import pandas as pd
import yfinance as yf

def calculate_buy_sell_volume(ticker):
    # Fetch historical data for the ticker using the Yahoo Finance API
    ticker_data = yf.download(ticker, start='2023-07-01', end='2023-07-05')
    
    # Extract the volume and assign 'is_buy' flag based on close price change
    ticker_data['is_buy'] = ticker_data['Close'].diff() > 0
    
    # Group the data by 'is_buy' column and calculate the sum of volume for each group
    volume_summary = ticker_data.groupby('is_buy')['Volume'].sum().reset_index()
    
    # Create a new DataFrame to store the buy and sell volume
    volume_df = pd.DataFrame(columns=['Buy Volume', 'Sell Volume'])
    volume_df.loc[0] = [0, 0]
    
    # Extract the buy and sell volume from the summary and store in the DataFrame
    for _, row in volume_summary.iterrows():
        if row['is_buy']:
            volume_df.loc[0, 'Buy Volume'] = row['Volume']
        else:
            volume_df.loc[0, 'Sell Volume'] = row['Volume']
    
    return volume_df

# Example usage
ticker_symbol = 'TSLA'  # Replace with your desired ticker symbol
volume_dataframe = calculate_buy_sell_volume(ticker_symbol)
print(volume_dataframe)

# %%
import pandas as pd
import yfinance as yf

def calculate_buy_sell_volume(ticker):
    # Fetch historical data for the ticker using the Yahoo Finance API
    ticker_data = yf.download(ticker, start='2010-07-05', end='2023-07-05')
    
    # Extract the volume and assign 'is_buy' flag based on close price change
    ticker_data['is_buy'] = ticker_data['Close'].diff() > 0
    
    # Group the data by 'is_buy' column and calculate the sum of volume for each group
    volume_summary = ticker_data.groupby('is_buy')['Volume'].sum().reset_index()
    
    # Create a new DataFrame to store the buy and sell volume
    volume_df = pd.DataFrame(columns=['Buy Volume', 'Sell Volume'])
    volume_df.loc[0] = [0, 0]
    
    # Extract the buy and sell volume from the summary and store in the DataFrame
    for _, row in volume_summary.iterrows():
        if row['is_buy']:
            volume_df.loc[0, 'Buy Volume'] = row['Volume']
        else:
            volume_df.loc[0, 'Sell Volume'] = row['Volume']
    
    return volume_df

# Example usage
ticker_symbol = 'TSLA'  # Replace with your desired ticker symbol
volume_dataframe = calculate_buy_sell_volume(ticker_symbol)
print(volume_dataframe)

# %%
import pandas as pd
import yfinance as yf

def calculate_buy_sell_volume(ticker):
    # Fetch historical data for the ticker using the Yahoo Finance API
    ticker_data = yf.download(ticker, start='2023-07-01', end='2023-07-05')
    
    # Extract the volume and assign 'is_buy' flag based on close price change
    ticker_data['is_buy'] = ticker_data['Close'].diff() > 0
    
    # Group the data by date and 'is_buy' column and calculate the sum of volume for each group
    volume_summary = ticker_data.groupby([ticker_data.index.date, 'is_buy'])['Volume'].sum().unstack(fill_value=0)
    
    # Reset the index and rename the columns
    volume_summary = volume_summary.reset_index()
    volume_summary.columns = ['Date', 'Sell Volume', 'Buy Volume']
    
    return volume_summary

# Example usage
ticker_symbol = 'TSLA'  # Replace with your desired ticker symbol
volume_dataframe = calculate_buy_sell_volume(ticker_symbol)
print(volume_dataframe)

# %%
import pandas as pd
import yfinance as yf

def calculate_buy_sell_volume(ticker):
    # Fetch historical data for the ticker using the Yahoo Finance API
    ticker_data = yf.download(ticker, start='2023-07-01', end='2023-07-05')
    
    # Extract the volume and assign 'is_buy' flag based on close price change
    ticker_data['is_buy'] = ticker_data['Close'].diff() > 0
    
    # Group the data by date and 'is_buy' column and calculate the sum of volume for each group
    volume_summary = ticker_data.groupby([ticker_data.index.date, 'is_buy'])['Volume'].sum().unstack(fill_value=0)
    
    # Reset the index and rename the columns
    volume_summary.reset_index(inplace=True)
    volume_summary.rename(columns={True: 'Buy Volume', False: 'Sell Volume'}, inplace=True)
    
    return volume_summary

# Example usage
ticker_symbol = 'TSLA'  # Replace with your desired ticker symbol
volume_dataframe = calculate_buy_sell_volume(ticker_symbol)
print(volume_dataframe)

# %%
import pandas as pd
import yfinance as yf

def calculate_buy_sell_volume(ticker, start_date, end_date):
    # Fetch historical data for the ticker using the Yahoo Finance API
    ticker_data = yf.download(ticker, start=start_date, end=end_date)
    
    # Extract the volume and assign 'is_buy' flag based on close price change
    ticker_data['is_buy'] = ticker_data['Close'].diff() > 0
    
    # Group the data by date and 'is_buy' column and calculate the sum of volume for each group
    volume_summary = ticker_data.groupby([ticker_data.index.date, 'is_buy'])['Volume'].sum().unstack(fill_value=0)
    
    # Reset the index and rename the columns
    volume_summary.reset_index(inplace=True)
    volume_summary.rename(columns={True: 'Buy Volume', False: 'Sell Volume'}, inplace=True)
    
    return volume_summary

# Example usage
ticker_symbol = 'TSLA'  # Replace with your desired ticker symbol
start_date = '2023-07-01'  # Replace with your desired start date
end_date = '2023-07-05'  # Replace with your desired end date
volume_dataframe = calculate_buy_sell_volume(ticker_symbol, start_date, end_date)
print(volume_dataframe)

# %%
import pandas as pd
import yfinance as yf

def calculate_buy_sell_volume(ticker, start_date, end_date):
    # Fetch historical data for the ticker using the Yahoo Finance API
    ticker_data = yf.download(ticker, start=start_date, end=end_date)
    
    # Extract the volume and assign 'is_buy' flag based on close price change
    ticker_data['is_buy'] = ticker_data['Close'].diff() > 0
    
    # Group the data by date and 'is_buy' column and calculate the sum of volume for each group
    volume_summary = ticker_data.groupby([ticker_data.index.date, 'is_buy'])['Volume'].sum().unstack(fill_value=0)
    
    # Reset the index and rename the columns
    volume_summary.reset_index(inplace=True)
    volume_summary.rename(columns={True: 'Buy Volume', False: 'Sell Volume'}, inplace=True)
    
    return volume_summary

# Example usage
ticker_symbol = 'TSLA'  # Replace with your desired ticker symbol
start_date = '2020-01-01'  # Replace with your desired start date
end_date = '2023-07-05'  # Replace with your desired end date
volume_dataframe = calculate_buy_sell_volume(ticker_symbol, start_date, end_date)
volume_dataframe.tail()

# %%
import pandas as pd
import yfinance as yf

def calculate_buy_sell_volume(ticker, start_date, end_date):
    # Fetch historical data for the ticker using the Yahoo Finance API
    ticker_data = yf.download(ticker, start=start_date, end=end_date)
    
    # Extract the volume and assign 'is_buy' flag based on close price change
    ticker_data['is_buy'] = ticker_data['Close'].diff() > 0
    
    # Group the data by date and 'is_buy' column and calculate the sum of volume for each group
    volume_summary = ticker_data.groupby([ticker_data.index.date, 'is_buy'])['Volume'].sum().unstack(fill_value=0)
    
    # Reset the index and rename the columns
    volume_summary.reset_index(inplace=True)
    
    # Calculate the sell volume as the complement of buy volume
    volume_summary['Sell Volume'] = volume_summary['Buy Volume'].apply(lambda x: 0 if x > 0 else abs(x))
    
    return volume_summary

# Example usage
ticker_symbol = 'TSLA'  # Replace with your desired ticker symbol
start_date = '2023-07-01'  # Replace with your desired start date
end_date = '2023-07-05'  # Replace with your desired end date
volume_dataframe = calculate_buy_sell_volume(ticker_symbol, start_date, end_date)
print(volume_dataframe)

# %%
import pandas as pd
import yfinance as yf

def calculate_buy_sell_volume(ticker, start_date, end_date):
    # Fetch historical data for the ticker using the Yahoo Finance API
    ticker_data = yf.download(ticker, start=start_date, end=end_date)
    
    # Extract the volume and assign 'is_buy' flag based on close price change
    ticker_data['is_buy'] = ticker_data['Close'].diff() > 0
    
    # Group the data by date and 'is_buy' column and calculate the sum of volume for each group
    volume_summary = ticker_data.groupby([ticker_data.index.date, 'is_buy'])['Volume'].sum().unstack(fill_value=0)
    
    # Reset the index and rename the columns
    volume_summary.reset_index(inplace=True)
    
    # Calculate the sell volume as the complement of buy volume, if 'Buy Volume' column exists
    if 'Buy Volume' in volume_summary.columns:
        volume_summary['Sell Volume'] = volume_summary['Buy Volume'].apply(lambda x: 0 if x > 0 else abs(x))
    else:
        volume_summary['Sell Volume'] = 0
    
    return volume_summary

# Example usage
ticker_symbol = 'TSLA'  # Replace with your desired ticker symbol
start_date = '2023-07-01'  # Replace with your desired start date
end_date = '2023-07-05'  # Replace with your desired end date
volume_dataframe = calculate_buy_sell_volume(ticker_symbol, start_date, end_date)
volume_dataframe.head()

# %%
def order_flow(buy_volume, sell_volume):
    return buy_volume - sell_volume

# Example usage
buy_volume = 1000
sell_volume = 800

result = order_flow(buy_volume, sell_volume)
print("Order Flow:", result)

# %%
import yfinance as yf

def order_flow(symbol):
    # Retrieve the historical data for the given symbol
    stock = yf.Ticker(symbol)
    history = stock.history(period='1d')

    # Get the volume data
    volumes = history['Volume']

    # Calculate the buy and sell volumes
    buy_volume = sum(volumes[volumes > 0])  # Assuming positive volumes indicate buy orders
    sell_volume = sum(volumes[volumes < 0])  # Assuming negative volumes indicate sell orders

    # Calculate and return the order flow
    return buy_volume - sell_volume

# Example usage
symbol = 'AAPL'
result = order_flow(symbol)
print("Order Flow for", symbol, ":", result)

# %%
import yfinance as yf

def order_flow(symbol):
    # Retrieve the historical data for the given symbol
    stock = yf.Ticker(symbol)
    history = stock.history(period='1d')

    # Get the volume data
    volumes = history['Volume']

    # Calculate the buy and sell volumes
    buy_volume = sum(volumes[volumes > 0])  # Assuming positive volumes indicate buy orders
    sell_volume = sum(volumes[volumes < 0])  # Assuming negative volumes indicate sell orders

    # Calculate the order flow
    order_flow_value = buy_volume - sell_volume

    # Determine the direction of the order flow
    if order_flow_value > 0:
        direction = 'Positive'
    elif order_flow_value < 0:
        direction = 'Negative'
    else:
        direction = 'Neutral'

    # Return the order flow and direction
    return order_flow_value, direction

# Example usage
symbol = 'AAPL'
result, flow_direction = order_flow(symbol)
print("Order Flow for", symbol, ":", result)
print("Order Flow Direction:", flow_direction)

# %%
import yfinance as yf
import pandas as pd

def order_flow(symbol):
    # Retrieve the historical data for the given symbol
    stock = yf.Ticker(symbol)
    history = stock.history(period='1d')

    # Get the volume data
    volumes = history['Volume']

    # Calculate the buy and sell volumes
    buy_volume = sum(volumes[volumes > 0])  # Assuming positive volumes indicate buy orders
    sell_volume = sum(volumes[volumes < 0])  # Assuming negative volumes indicate sell orders

    # Calculate the order flow
    order_flow_value = buy_volume - sell_volume

    # Determine the direction of the order flow
    if order_flow_value > 0:
        direction = 'Positive'
    elif order_flow_value < 0:
        direction = 'Negative'
    else:
        direction = 'Neutral'

    # Create a DataFrame with the order flow result
    data = {'Symbol': [symbol],
            'Order Flow': [order_flow_value],
            'Direction': [direction]}
    df = pd.DataFrame(data)

    return df

# Example usage
symbol = 'AAPL'
result_df = order_flow(symbol)
print(result_df)

# %%
import yfinance as yf
import pandas as pd

def order_flow(symbol, start_date, end_date):
    # Retrieve the historical data for the given symbol and time period
    stock = yf.Ticker(symbol)
    history = stock.history(start=start_date, end=end_date)

    # Get the volume data
    volumes = history['Volume']

    # Calculate the buy and sell volumes
    buy_volume = sum(volumes[volumes > 0])  # Assuming positive volumes indicate buy orders
    sell_volume = sum(volumes[volumes < 0])  # Assuming negative volumes indicate sell orders

    # Calculate the order flow
    order_flow_value = buy_volume - sell_volume

    # Determine the direction of the order flow
    if order_flow_value > 0:
        direction = 'Positive'
    elif order_flow_value < 0:
        direction = 'Negative'
    else:
        direction = 'Neutral'

    # Create a DataFrame with the order flow result
    data = {'Symbol': [symbol],
            'Order Flow': [order_flow_value],
            'Direction': [direction]}
    df = pd.DataFrame(data)

    return df

# Example usage
symbol = 'AAPL'
start_date = '2023-01-01'
end_date = '2023-06-30'
result_df = order_flow(symbol, start_date, end_date)
result_df.head()

# %%
import yfinance as yf
import pandas as pd

def order_flow(symbol, start_date, end_date):
    # Retrieve the historical data for the given symbol and time period
    stock = yf.Ticker(symbol)
    history = stock.history(start=start_date, end=end_date)

    # Get the volume data and corresponding dates
    volumes = history['Volume']
    dates = history.index

    # Calculate the buy and sell volumes for each day
    buy_volumes = volumes[volumes > 0]  # Assuming positive volumes indicate buy orders
    sell_volumes = volumes[volumes < 0]  # Assuming negative volumes indicate sell orders

    # Create a DataFrame with the order flow results for each day
    data = {'Date': dates,
            'Buy Volume': buy_volumes,
            'Sell Volume': sell_volumes}
    df = pd.DataFrame(data)

    # Calculate the order flow for each day
    df['Order Flow'] = df['Buy Volume'] - df['Sell Volume']

    # Determine the direction of the order flow for each day
    df['Direction'] = df['Order Flow'].apply(lambda x: 'Positive' if x > 0 else ('Negative' if x < 0 else 'Neutral'))

    return df

# Example usage
symbol = 'AAPL'
start_date = '2023-01-01'
end_date = '2023-06-30'
result_df = order_flow(symbol, start_date, end_date)
result_df.

# %%
import requests
import pandas as pd

def order_flow(symbol, api_key):
    # Make API request to Alpha Vantage
    url = f"https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&apikey={api_key}"
    response = requests.get(url)
    data = response.json()

    # Extract volume data
    time_series = data['Time Series (Daily)']
    df = pd.DataFrame.from_dict(time_series, orient='index')
    df.index = pd.to_datetime(df.index)
    df.columns = [col.split()[-1] for col in df.columns]

    # Calculate the order flow
    df['Order Flow'] = df['buy'] - df['sell']

    # Determine the direction of the order flow
    df['Direction'] = df['Order Flow'].apply(lambda x: 'Positive' if x > 0 else ('Negative' if x < 0 else 'Neutral'))

    return df

# Example usage
symbol = 'AAPL'
api_key = 'YOUR_API_KEY'  # Replace with your Alpha Vantage API key
result_df = order_flow(symbol, api_key)
print(result_df)

# %%
import requests
import pandas as pd

def order_flow(symbol, api_key):
    # Make API request to Alpha Vantage
    url = f"https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&apikey={api_key}"
    response = requests.get(url)
    data = response.json()

    # Check if the API request was successful
    if 'Time Series (Daily)' not in data:
        print("API request failed. Please check the symbol and API key.")
        return None

    # Extract volume data
    time_series = data['Time Series (Daily)']
    df = pd.DataFrame.from_dict(time_series, orient='index')
    df.index = pd.to_datetime(df.index)
    df.columns = [col.split()[-1] for col in df.columns]

    # Calculate the order flow
    df['Order Flow'] = df['5. volume'].astype(int)

    # Determine the direction of the order flow
    df['Direction'] = df['Order Flow'].apply(lambda x: 'Positive' if x > 0 else ('Negative' if x < 0 else 'Neutral'))

    return df

# Example usage
symbol = 'AAPL'
api_key = 'YOUR_API_KEY'  # Replace with your Alpha Vantage API key
result_df = order_flow(symbol, api_key)
print(result_df)

# %%
import requests
import pandas as pd

def order_flow(symbol, api_key):
    # Make API request to Alpha Vantage
    url = f"https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&apikey={api_key}"
    response = requests.get(url)
    data = response.json()

    # Check if the API request was successful
    if 'Time Series (Daily)' not in data:
        print("API request failed. Please check the symbol and API key.")
        return None

    # Extract volume data
    time_series = data['Time Series (Daily)']
    df = pd.DataFrame.from_dict(time_series, orient='index')
    df.index = pd.to_datetime(df.index)
    df.columns = [col.split()[-1] for col in df.columns]

    # Calculate the order flow
    df['Order Flow'] = df['5. volume'].astype(int)

    # Determine the direction of the order flow
    df['Direction'] = df['Order Flow'].apply(lambda x: 'Positive' if x > 0 else ('Negative' if x < 0 else 'Neutral'))

    return df

# Example usage
symbol = 'AAPL'
api_key = '1EG0LC5VU6TUM8N3'  # Replace with your actual Alpha Vantage API key
result_df = order_flow(symbol, api_key)
print(result_df)

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2023-07-06"

# Fetch historical data from Yahoo Finance API
data = yf.download(ticker, start=start_date, end=end_date)

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    ask_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    bid_volume = data['Volume'].iloc[i]
    ask_volume = data['Volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * data['Volume'].iloc[i-1] - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * data['Volume'].iloc[i-1]

data['ofi'] = e

# using OFI for trading signal generation
data['signal'] = np.where(data['ofi'] > 0, 1, -1)

# Print the updated dataframe
data.tail()

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2020-01-01"
end_date = "2022-12-31"

# Fetch historical data from Yahoo Finance API
data = yf.download(ticker, start=start_date, end=end_date)

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    ask_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    bid_volume = data['Volume'].iloc[i]
    ask_volume = data['Volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * data['Volume'].iloc[i-1] - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * data['Volume'].iloc[i-1]

data['ofi'] = e

# Plot the OFI values
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['ofi'], color='blue')
plt.xlabel('Date')
plt.ylabel('OFI')
plt.title('Order Flow Imbalance (OFI)')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2022-12-31"

# Fetch hourly historical data from Yahoo Finance API
data = yf.download(ticker, start=start_date, end=end_date, interval="1h")

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    ask_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    bid_volume = data['Volume'].iloc[i]
    ask_volume = data['Volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * bid_volume - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * ask_volume

data['ofi'] = e

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2022-12-31"

# Fetch hourly historical data from Yahoo Finance API
data = yf.download(ticker, start=start_date, end=end_date, interval="1h")

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    ask_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    bid_volume = data['Volume'].iloc[i]
    ask_volume = data['Volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * bid_volume - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * ask_volume

data['ofi'] = e

# Print the data with OFI values
data.tail()

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2023-01-01"
end_date = "2023-07-06"

# Fetch hourly historical data from Yahoo Finance API
data = yf.download(ticker, start=start_date, end=end_date, interval="1h")

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    ask_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    bid_volume = data['Volume'].iloc[i]
    ask_volume = data['Volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * bid_volume - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * ask_volume

data['ofi'] = e

# Calculate trading signals based on OFI
data['signal'] = np.where(data['ofi'] > 0, 1, -1)

# Print the data with OFI values and trading signals
data.tail()

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Set Pandas display options
pd.set_option('display.max_rows', None)

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2023-01-01"
end_date = "2023-07-31"

# Fetch hourly historical data from Yahoo Finance API
data = yf.download(ticker, start=start_date, end=end_date, interval="1h")

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    ask_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    bid_volume = data['Volume'].iloc[i]
    ask_volume = data['Volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * bid_volume - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * ask_volume

data['ofi'] = e

# Calculate trading signals based on OFI
data['signal'] = np.where(data['ofi'] > 0, 1, -1)

# Print the data with OFI values and trading signals
data

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Set Pandas display options
pd.set_option('display.max_rows', None)

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2022-12-31"

# Fetch hourly historical data from Yahoo Finance API
data = yf.download(ticker, start=start_date, end=end_date, interval="5d")

# Calculate Pivot Points
data['Pivot'] = (data['High'] + data['Low'] + data['Close']) / 3
data['R1'] = 2 * data['Pivot'] - data['Low']
data['S1'] = 2 * data['Pivot'] - data['High']

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    ask_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    bid_volume = data['Volume'].iloc[i]
    ask_volume = data['Volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * bid_volume - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * ask_volume

data['ofi'] = e

# Calculate trading signals based on OFI and Pivot Points
data['signal'] = np.where((data['ofi'] > 0) & (data['Low'] > data['S1']), 1,
                          np.where((data['ofi'] < 0) & (data['High'] < data['R1']), -1, 0))

# Print the data with OFI values, Pivot Points, and trading signals
data

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Set Pandas display options
pd.set_option('display.max_rows', None)

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2022-12-31"

# Fetch hourly historical data from Yahoo Finance API
data = yf.download(ticker, start=start_date, end=end_date, interval="1h")

# Calculate Pivot Points
data['Pivot'] = (data['High'] + data['Low'] + data['Close']) / 3
data['R1'] = 2 * data['Pivot'] - data['Low']
data['S1'] = 2 * data['Pivot'] - data['High']

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    ask_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    bid_volume = data['Volume'].iloc[i]
    ask_volume = data['Volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * bid_volume - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * ask_volume

data['ofi'] = e

# Calculate trading signals based on OFI and Pivot Points
data['signal'] = np.where((data['ofi'] > 0) & (data['Low'] > data['S1']), 1,
                          np.where((data['ofi'] < 0) & (data['High'] < data['R1']), -1, 0))

# Calculate the new amount based on the signals
starting_amount = 100000
data['new_amount'] = starting_amount + (data['signal'].shift(1) * data['Close'].pct_change()).cumsum().fillna(0)

# Print the data with OFI values, Pivot Points, trading signals, and new amount
data.head()

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Set Pandas display options
pd.set_option('display.max_rows', None)

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2022-12-31"

# Fetch hourly historical data from Yahoo Finance API
data = yf.download(ticker, start=start_date, end=end_date, interval="1h")

# Calculate Pivot Points
data['Pivot'] = (data['High'] + data['Low'] + data['Close']) / 3
data['R1'] = 2 * data['Pivot'] - data['Low']
data['S1'] = 2 * data['Pivot'] - data['High']

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    ask_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    bid_volume = data['Volume'].iloc[i]
    ask_volume = data['Volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * bid_volume - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * ask_volume

data['ofi'] = e

# Calculate trading signals based on OFI and Pivot Points
data['signal'] = np.where((data['ofi'] > 0) & (data['Low'] > data['S1']), 1,
                          np.where((data['ofi'] < 0) & (data['High'] < data['R1']), -1, 0))

# Calculate the new amount based on the signals using 100 lots to buy
starting_amount = 100000
lot_size = 100
data['new_amount'] = starting_amount + (data['signal'].shift(1) * lot_size * data['Close'].pct_change()).cumsum().fillna(0)

# Print the data with OFI values, Pivot Points, trading signals, and new amount
data.head()

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2022-12-31"

# Fetch hourly historical data from Yahoo Finance API
data = yf.download(ticker, start=start_date, end=end_date, interval="1h")

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    ask_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    bid_volume = data['Volume'].iloc[i]
    ask_volume = data['Volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * bid_volume - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * ask_volume

data['ofi'] = e

# Calculate average volume
average_volume = data['Volume'].mean()

# Add column for volume comparison
data['Volume Comparison'] = np.where(data['Volume'] > average_volume, 'Greater', 'Lower')

# Print the data with OFI values and volume comparison
data.tail()

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2022-12-31"

# Fetch hourly historical data from Yahoo Finance API
data = yf.download(ticker, start=start_date, end=end_date, interval="1h")

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    ask_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    bid_volume = data['Volume'].iloc[i]
    ask_volume = data['Volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * bid_volume - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * ask_volume

data['ofi'] = e

# Calculate average volume
average_volume = data['Volume'].mean()

# Add column for average volume
data['Average Volume'] = average_volume

# Print the data with OFI values and average volume
data.head()

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Set Pandas display options
pd.options.display.float_format = '{:.2f}'.format

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2022-12-31"

# Fetch hourly historical data from Yahoo Finance API
data = yf.download(ticker, start=start_date, end=end_date, interval="1h")

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    ask_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    bid_volume = data['Volume'].iloc[i]
    ask_volume = data['Volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * bid_volume - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * ask_volume

data['ofi'] = e

# Calculate average volume
average_volume = data['Volume'].mean()

# Add column for average volume
data['Average Volume'] = average_volume

# Print the data with OFI values and average volume
data.tail()

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2022-12-31"
interval = "1h"

# Fetch hourly historical data from Yahoo Finance API
data = yf.download(ticker, start=start_date, end=end_date, interval=interval)

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    ask_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    bid_volume = data['Volume'].iloc[i]
    ask_volume = data['Volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * bid_volume - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * ask_volume

data['ofi'] = e

# Calculate average volume within the specified interval
average_volume = data['Volume'].rolling(interval).mean()

# Add column for average volume
data['Average Volume'] = average_volume

# Print the data with OFI values and average volume
data.tail()

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2022-12-31"

# Fetch hourly historical data from Yahoo Finance API
data = yf.download(ticker, start=start_date, end=end_date, interval="1h")

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    ask_change = data['Close'].iloc[i] - data['Close'].iloc[i-1]
    bid_volume = data['Volume'].iloc[i]
    ask_volume = data['Volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * bid_volume - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * ask_volume

data['ofi'] = e

# Calculate average volume for each trading day
average_volume = data['Volume'].resample('D').mean()

# Add column for average volume
data['Average Volume'] = average_volume.reindex(data.index, method='ffill')

# Print the data with OFI values and average volume
data

# %%
import pandas as pd
import numpy as np
import alpaca_trade_api as tradeapi

# Define Alpaca API credentials
api_key = 'PK5IRS4UE8JDHNQOFRG1'
base_url = 'https://paper-api.alpaca.markets'  # Use 'https://api.alpaca.markets' for live trading

# Create Alpaca API connection
api = tradeapi.REST(api_key, base_url, api_version='v2')

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2023-07-06"

# Fetch historical data from Alpaca API
data = api.get_barset(symbols=ticker, timeframe='1D', start=start_date, end=end_date).df[ticker]

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['close'].iloc[i] - data['close'].iloc[i-1]
    ask_change = data['close'].iloc[i] - data['close'].iloc[i-1]
    bid_volume = data['volume'].iloc[i]
    ask_volume = data['volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * data['volume'].iloc[i-1] - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * data['volume'].iloc[i-1]

data['ofi'] = e

# Using OFI for trading signal generation
data['signal'] = np.where(data['ofi'] > 0, 1, -1)

# Print the updated dataframe
print(data.tail())

# %%
import pandas as pd
import numpy as np
import alpaca_trade_api as tradeapi

# Define Alpaca API credentials
api_key = 'PK5IRS4UE8JDHNQOFRG1'
base_url = 'https://paper-api.alpaca.markets'  # Use 'https://api.alpaca.markets' for live trading

# Create Alpaca API connection
api = tradeapi.REST(api_key, base_url, api_version='v2')

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2023-07-06"

# Fetch historical data from Alpaca API
data = api.get_barset(symbols=ticker, timeframe='1D', start=start_date, end=end_date).df[ticker]

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['close'].iloc[i] - data['close'].iloc[i-1]
    ask_change = data['close'].iloc[i] - data['close'].iloc[i-1]
    bid_volume = data['volume'].iloc[i]
    ask_volume = data['volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * data['volume'].iloc[i-1] - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * data['volume'].iloc[i-1]

data['ofi'] = e

# Using OFI for trading signal generation
data['signal'] = np.where(data['ofi'] > 0, 1, -1)

# Print the updated dataframe
data.tail()

# %%
# !pip install --upgrade alpaca-trade-api

# %%
import pandas as pd
import numpy as np
import alpaca_trade_api as tradeapi

# Define Alpaca API credentials
api_key = 'PK5IRS4UE8JDHNQOFRG1'
base_url = 'https://paper-api.alpaca.markets'  # Use 'https://api.alpaca.markets' for live trading

# Create Alpaca API connection
api = tradeapi.REST(api_key, base_url, api_version='v2')

# Define the ticker symbol and timeframe
ticker = "AAPL"
start_date = "2022-01-01"
end_date = "2023-07-06"

# Fetch historical data from Alpaca API
data = api.get_barset(symbols=ticker, timeframe='1D', start=start_date, end=end_date).df[ticker]

# Calculate Order Flow Imbalance (OFI)
e = np.zeros(len(data))
for i in range(1, len(data)):
    bid_change = data['close'].iloc[i] - data['close'].iloc[i-1]
    ask_change = data['close'].iloc[i] - data['close'].iloc[i-1]
    bid_volume = data['volume'].iloc[i]
    ask_volume = data['volume'].iloc[i]
    
    e[i] = (bid_change >= 0) * bid_volume - (bid_change < 0) * data['volume'].iloc[i-1] - \
           (ask_change <= 0) * ask_volume + (ask_change > 0) * data['volume'].iloc[i-1]

data['ofi'] = e

# Using OFI for trading signal generation
data['signal'] = np.where(data['ofi'] > 0, 1, -1)

# Print the updated dataframe
print(data.tail())

# %%
import alpaca_trade_api as tradeapi
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd
# Define your keys
import alpaca_trade_api as tradeapi
# API Info for fetching data, portfolio, etc. from Alpaca
BASE_URL = 'https://paper-api.alpaca.markets'
ALPACA_API_KEY = "PK5IRS4UE8JDHNQOFRG1"
uGSpaYhZCwVmqfo4Aqdj8UxqstnCveZHSWb408IB
# Instantiate REST API Connection
api = tradeapi.REST(key_id=ALPACA_API_KEY, secret_key=ALPACA_SECRET_KEY,
                    base_url=BASE_URL, api_version='v2')
# Define the date range (last 4 months)
end_date = datetime.now()
start_date = end_date - timedelta(days=4*30)
# Fetch daily data for Apple stock
symbol = 'AAPL'
stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1h')
# Existing code for calculating pivot points, support/resistance, etc.
pivot_point = (stock_data['High'] + stock_data['Low'] + stock_data['Close']) / 3
# Calculate support and resistance levels
first_support = (2 * pivot_point) - stock_data['High']
first_resistance = (2 * pivot_point) - stock_data['Low']
second_support = pivot_point - (stock_data['High'] - stock_data['Low'])
second_resistance = pivot_point + (stock_data['High'] - stock_data['Low'])
third_support = pivot_point - 2 * (stock_data['High'] - stock_data['Low'])
third_resistance = pivot_point + 2 * (stock_data['High'] - stock_data['Low'])
# Create a new DataFrame to store the pivot points and support/resistance levels
pivot_df = pd.DataFrame(index=stock_data.index)
pivot_df['Pivot'] = pivot_point
pivot_df['Support 1'] = first_support
pivot_df['Resistance 1'] = first_resistance
pivot_df['Support 2'] = second_support
pivot_df['Resistance 2'] = second_resistance
pivot_df['Support 3'] = third_support
pivot_df['Resistance 3'] = third_resistance
# Merge the pivot DataFrame with the stock data DataFrame
stock_data_with_pivot = pd.concat([stock_data, pivot_df], axis=1)
# Create signals based on pivot points
stock_data_with_pivot['Signal'] = 0
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 1'], 'Signal'] = 1
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 2'], 'Signal'] = 2
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 3'], 'Signal'] = 3
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 1'], 'Signal'] = -1
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 2'], 'Signal'] = -2
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 3'], 'Signal'] = -3
# Generate trading orders based on the signals
from alpaca_trade_api.rest import APIError
for index, row in stock_data_with_pivot.iterrows():
    try:
        if row['Signal'] > 0:
            api.submit_order(
                symbol=symbol,
                qty='100',
                side='buy',
                type='market',
                time_in_force='gtc'
            )
        elif row['Signal'] < 0:
            # Get the current position to ensure we don't short sell
            position = api.get_position(symbol)
            if position.qty >= 100:  # Adjust this value as needed
                api.submit_order(
                    symbol=symbol,
                    qty='100',
                    side='sell',
                    type='market',
                    time_in_force='gtc'
                )
    except APIError as e:
        print(f'Error when processing order for {symbol}: {str(e)}')

# %%
import alpaca_trade_api as tradeapi
# authentication and connection details
base_url = "https://paper-api.alpaca.markets"
api_key = "PK5IRS4UE8JDHNQOFRG1"
# instantiate REST API
api = tradeapi.REST(api_key, api_secret, base_url, api_version='v2')
# obtain account information
account = api.get_account()
print(account)

# %%
import alpaca_trade_api as tradeapi
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd
# Define your keys
import alpaca_trade_api as tradeapi
# API Info for fetching data, portfolio, etc. from Alpaca
BASE_URL = "https://paper-api.alpaca.markets"
ALPACA_API_KEY = "PKSZXS4Q79O1VIXILWAS"
ALPACA_SECRET_KEY = "Ekki5szEyl4MtqHZzh788ZF8kIi43DEEmxmT8k6S"
# Instantiate REST API Connection
api = tradeapi.REST(key_id=ALPACA_API_KEY, secret_key=ALPACA_SECRET_KEY,
                    base_url=BASE_URL)
# Define the date range (last 4 months)
end_date = datetime.now()
start_date = end_date - timedelta(days=4*30)
# Fetch daily data for Apple stock
symbol = 'AAPL'
stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1h')
# Existing code for calculating pivot points, support/resistance, etc.
pivot_point = (stock_data['High'] + stock_data['Low'] + stock_data['Close']) / 3
# Calculate support and resistance levels
first_support = (2 * pivot_point) - stock_data['High']
first_resistance = (2 * pivot_point) - stock_data['Low']
second_support = pivot_point - (stock_data['High'] - stock_data['Low'])
second_resistance = pivot_point + (stock_data['High'] - stock_data['Low'])
third_support = pivot_point - 2 * (stock_data['High'] - stock_data['Low'])
third_resistance = pivot_point + 2 * (stock_data['High'] - stock_data['Low'])
# Create a new DataFrame to store the pivot points and support/resistance levels
pivot_df = pd.DataFrame(index=stock_data.index)
pivot_df['Pivot'] = pivot_point
pivot_df['Support 1'] = first_support
pivot_df['Resistance 1'] = first_resistance
pivot_df['Support 2'] = second_support
pivot_df['Resistance 2'] = second_resistance
pivot_df['Support 3'] = third_support
pivot_df['Resistance 3'] = third_resistance
# Merge the pivot DataFrame with the stock data DataFrame
stock_data_with_pivot = pd.concat([stock_data, pivot_df], axis=1)
# Create signals based on pivot points
stock_data_with_pivot['Signal'] = 0
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 1'], 'Signal'] = 1
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 2'], 'Signal'] = 2
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 3'], 'Signal'] = 3
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 1'], 'Signal'] = -1
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 2'], 'Signal'] = -2
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 3'], 'Signal'] = -3
# Generate trading orders based on the signals
from alpaca_trade_api.rest import APIError
for index, row in stock_data_with_pivot.iterrows():
    try:
        if row['Signal'] > 0:
            api.submit_order(
                symbol=symbol,
                qty='100',
                side='buy',
                type='market',
                time_in_force='gtc'
            )
        elif row['Signal'] < 0:
            # Get the current position to ensure we don't short sell
            position = api.get_position(symbol)
            if position.qty >= 100:  # Adjust this value as needed
                api.submit_order(
                    symbol=symbol,
                    qty='100',
                    side='sell',
                    type='market',
                    time_in_force='gtc'
                )
    except APIError as e:
        print(f'Error when processing order for {symbol}: {str(e)}')
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 53
#      51 try:
#      52     if row['Signal'] > 0:
# ---> 53         api.submit_order(
#      54             symbol=symbol,
#      55             qty='100',
#      56             side='buy',
#      57             type='market',
#      58             time_in_force='gtc'
#      59         )
#      60     elif row['Signal'] < 0:
#      61         # Get the current position to ensure we don't short sell
#      62         position = api.get_position(symbol)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\alpaca_trade_api\rest.py:429, in REST.submit_order(self, symbol, qty, side, type, time_in_force, limit_price, stop_price, client_order_id, extended_hours, order_class, take_profit, stop_loss, trail_price, trail_percent, notional)
# ...

# %%
import alpaca_trade_api as tradeapi
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd

# Define your keys
BASE_URL = "https://paper-api.alpaca.markets"
ALPACA_API_KEY = "PKSZXS4Q79O1VIXILWAS"
ALPACA_SECRET_KEY = "Ekki5szEyl4MtqHZzh788ZF8kIi43DEEmxmT8k6S"

# Instantiate REST API Connection
api = tradeapi.REST(key_id=ALPACA_API_KEY, secret_key=ALPACA_SECRET_KEY, base_url=BASE_URL)

# Define the date range for backtesting (last 4 months)
end_date = datetime.now()
start_date = end_date - timedelta(days=4 * 30)

# Fetch daily data for Apple stock
symbol = 'AAPL'
stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1d')

# Existing code for calculating pivot points, support/resistance, etc.
pivot_point = (stock_data['High'] + stock_data['Low'] + stock_data['Close']) / 3

# Calculate support and resistance levels
first_support = (2 * pivot_point) - stock_data['High']
first_resistance = (2 * pivot_point) - stock_data['Low']
second_support = pivot_point - (stock_data['High'] - stock_data['Low'])
second_resistance = pivot_point + (stock_data['High'] - stock_data['Low'])
third_support = pivot_point - 2 * (stock_data['High'] - stock_data['Low'])
third_resistance = pivot_point + 2 * (stock_data['High'] - stock_data['Low'])

# Create a new DataFrame to store the pivot points and support/resistance levels
pivot_df = pd.DataFrame(index=stock_data.index)
pivot_df['Pivot'] = pivot_point
pivot_df['Support 1'] = first_support
pivot_df['Resistance 1'] = first_resistance
pivot_df['Support 2'] = second_support
pivot_df['Resistance 2'] = second_resistance
pivot_df['Support 3'] = third_support
pivot_df['Resistance 3'] = third_resistance

# Merge the pivot DataFrame with the stock data DataFrame
stock_data_with_pivot = pd.concat([stock_data, pivot_df], axis=1)

# Create signals based on pivot points
stock_data_with_pivot['Signal'] = 0
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 1'], 'Signal'] = 1
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 2'], 'Signal'] = 2
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 3'], 'Signal'] = 3
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 1'], 'Signal'] = -1
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 2'], 'Signal'] = -2
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 3'], 'Signal'] = -3

# Generate trading orders based on the signals
backtest_results = pd.DataFrame(index=stock_data_with_pivot.index, columns=['Order', 'Price', 'Quantity'])
for index, row in stock_data_with_pivot.iterrows():
    if row['Signal'] > 0:
        backtest_results.loc[index, 'Order'] = 'Buy'
        backtest_results.loc[index, 'Price'] = stock_data_with_pivot.loc[index, 'Close']
        backtest_results.loc[index, 'Quantity'] = 100
    elif row['Signal'] < 0:
        backtest_results.loc[index, 'Order'] = 'Sell'
        backtest_results.loc[index, 'Price'] = stock_data_with_pivot.loc[index, 'Close']
        backtest_results.loc[index, 'Quantity'] = 100

# %%
import alpaca_trade_api as tradeapi
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd

# Define your keys
BASE_URL = "https://paper-api.alpaca.markets"
ALPACA_API_KEY = "PKSZXS4Q79O1VIXILWAS"
ALPACA_SECRET_KEY = "Ekki5szEyl4MtqHZzh788ZF8kIi43DEEmxmT8k6S"

# Instantiate REST API Connection
api = tradeapi.REST(key_id=ALPACA_API_KEY, secret_key=ALPACA_SECRET_KEY, base_url=BASE_URL)

# Define the date range for backtesting (last 4 months)
end_date = datetime.now()
start_date = end_date - timedelta(days=4 * 30)

# Fetch daily data for Apple stock
symbols = ['AAPL', 'TSLA', 'SPY']
backtest_results = pd.DataFrame(columns=['Symbol', 'Order', 'Price', 'Quantity'])

for symbol in symbols:
    stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1d')

    # Existing code for calculating pivot points, support/resistance, etc.
    pivot_point = (stock_data['High'] + stock_data['Low'] + stock_data['Close']) / 3

    # Calculate support and resistance levels
    first_support = (2 * pivot_point) - stock_data['High']
    first_resistance = (2 * pivot_point) - stock_data['Low']
    second_support = pivot_point - (stock_data['High'] - stock_data['Low'])
    second_resistance = pivot_point + (stock_data['High'] - stock_data['Low'])
    third_support = pivot_point - 2 * (stock_data['High'] - stock_data['Low'])
    third_resistance = pivot_point + 2 * (stock_data['High'] - stock_data['Low'])

    # Create a new DataFrame to store the pivot points and support/resistance levels
    pivot_df = pd.DataFrame(index=stock_data.index)
    pivot_df['Pivot'] = pivot_point
    pivot_df['Support 1'] = first_support
    pivot_df['Resistance 1'] = first_resistance
    pivot_df['Support 2'] = second_support
    pivot_df['Resistance 2'] = second_resistance
    pivot_df['Support 3'] = third_support
    pivot_df['Resistance 3'] = third_resistance

    # Merge the pivot DataFrame with the stock data DataFrame
    stock_data_with_pivot = pd.concat([stock_data, pivot_df], axis=1)

    # Create signals based on pivot points
    stock_data_with_pivot['Signal'] = 0
    stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 1'], 'Signal'] = 1
    stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 2'], 'Signal'] = 2
    stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 3'], 'Signal'] = 3
    stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 1'], 'Signal'] = -1
    stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 2'], 'Signal'] = -2
    stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 3'], 'Signal'] = -3

    # Generate trading orders based on the signals
    for index, row in stock_data_with_pivot.iterrows():
        if row['Signal'] > 0:
            backtest_results = backtest_results.append(
                {'Symbol': symbol, 'Order': 'Buy', 'Price': stock_data_with_pivot.loc[index, 'Close'],
                 'Quantity': 100}, ignore_index=True)
        elif row['Signal'] < 0:
            backtest_results = backtest_results.append(
                {'Symbol': symbol, 'Order': 'Sell', 'Price': stock_data_with_pivot.loc[index, 'Close'],
                 'Quantity': 100}, ignore_index=True)

# Implement the day trading rule
day_trades = 0
for index, row in backtest_results.iterrows():
    if row['Order'] != 'Hold':
        day_trades += 1
    if day_trades > 3:
        backtest_results.at[index, 'Order'] = 'Hold'

# Execute the trading orders
for index, row in backtest_results.iterrows():
    symbol = row['Symbol']
    if row['Order'] == 'Buy':
        try:
            api.submit_order(
                symbol=symbol,
                qty=row['Quantity'],
                side='buy',
                type='market',
                time_in_force='gtc'
            )
            print(f"Submitted buy order for {row['Quantity']} {symbol} at {row['Price']}")
        except tradeapi.rest.APIError as e:
            print(f'Error when submitting buy order for {symbol}: {str(e)}')
    elif row['Order'] == 'Sell':
        try:
            api.submit_order(
                symbol=symbol,
                qty=row['Quantity'],
                side='sell',
                type='market',
                time_in_force='gtc'
            )
            print(f"Submitted sell order for {row['Quantity']} {symbol} at {row['Price']}")
        except tradeapi.rest.APIError as e:
            print(f'Error when submitting sell order for {symbol}: {str(e)}')
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 61
#      59 for index, row in stock_data_with_pivot.iterrows():
#      60     if row['Signal'] > 0:
# ---> 61         backtest_results = backtest_results.append(
#      62             {'Symbol': symbol, 'Order': 'Buy', 'Price': stock_data_with_pivot.loc[index, 'Close'],
#      63              'Quantity': 100}, ignore_index=True)
#      64     elif row['Signal'] < 0:
#      65         backtest_results = backtest_results.append(
#      66             {'Symbol': symbol, 'Order': 'Sell', 'Price': stock_data_with_pivot.loc[index, 'Close'],
#      67              'Quantity': 100}, ignore_index=True)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
# ...

# %%
import alpaca_trade_api as tradeapi
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd

# Define your keys
BASE_URL = "https://paper-api.alpaca.markets"
ALPACA_API_KEY = "PKSZXS4Q79O1VIXILWAS"
ALPACA_SECRET_KEY = "Ekki5szEyl4MtqHZzh788ZF8kIi43DEEmxmT8k6S"

# Instantiate REST API Connection
api = tradeapi.REST(key_id=ALPACA_API_KEY, secret_key=ALPACA_SECRET_KEY, base_url=BASE_URL)

# Define the date range for backtesting (last 4 months)
end_date = datetime.now()
start_date = end_date - timedelta(days=4 * 30)

# Fetch daily data for Apple stock
symbols = ['AAPL']
backtest_results = []

for symbol in symbols:
    stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1d')

    # Existing code for calculating pivot points, support/resistance, etc.
    pivot_point = (stock_data['High'] + stock_data['Low'] + stock_data['Close']) / 3

    # Calculate support and resistance levels
    first_support = (2 * pivot_point) - stock_data['High']
    first_resistance = (2 * pivot_point) - stock_data['Low']
    second_support = pivot_point - (stock_data['High'] - stock_data['Low'])
    second_resistance = pivot_point + (stock_data['High'] - stock_data['Low'])
    third_support = pivot_point - 2 * (stock_data['High'] - stock_data['Low'])
    third_resistance = pivot_point + 2 * (stock_data['High'] - stock_data['Low'])

    # Create a new DataFrame to store the pivot points and support/resistance levels
    pivot_df = pd.DataFrame(index=stock_data.index)
    pivot_df['Pivot'] = pivot_point
    pivot_df['Support 1'] = first_support
    pivot_df['Resistance 1'] = first_resistance
    pivot_df['Support 2'] = second_support
    pivot_df['Resistance 2'] = second_resistance
    pivot_df['Support 3'] = third_support
    pivot_df['Resistance 3'] = third_resistance

    # Merge the pivot DataFrame with the stock data DataFrame
    stock_data_with_pivot = pd.concat([stock_data, pivot_df], axis=1)

    # Create signals based on pivot points
    stock_data_with_pivot['Signal'] = 0
    stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 1'], 'Signal'] = 1
    stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 2'], 'Signal'] = 2
    stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 3'], 'Signal'] = 3
    stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 1'], 'Signal'] = -1
    stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 2'], 'Signal'] = -2
    stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 3'], 'Signal'] = -3

    # Generate trading orders based on the signals
    for index, row in stock_data_with_pivot.iterrows():
        if row['Signal'] > 0:
            backtest_results.append(
                {'Symbol': symbol, 'Order': 'Buy', 'Price': stock_data_with_pivot.loc[index, 'Close'],
                 'Quantity': 100})
        elif row['Signal'] < 0:
            backtest_results.append(
                {'Symbol': symbol, 'Order': 'Sell', 'Price': stock_data_with_pivot.loc[index, 'Close'],
                 'Quantity': 100})

# Implement the day trading rule
day_trades = 0
for result in backtest_results:
    if result['Order'] != 'Hold':
        day_trades += 1
    if day_trades > 3:
        result['Order'] = 'Hold'

# Convert the list of dictionaries into a DataFrame
backtest_results = pd.DataFrame(backtest_results)

# Execute the trading orders
for index, row in backtest_results.iterrows():
    symbol = row['Symbol']
    if row['Order'] == 'Buy':
        try:
            api.submit_order(
                symbol=symbol,
                qty=row['Quantity'],
                side='buy',
                type='market',
                time_in_force='gtc'
            )
            print(f"Submitted buy order for {row['Quantity']} {symbol} at {row['Price']}")
        except tradeapi.rest.APIError as e:
            print(f'Error when submitting buy order for {symbol}: {str(e)}')
    elif row['Order'] == 'Sell':
        try:
            api.submit_order(
                symbol=symbol,
                qty=row['Quantity'],
                side='sell',
                type='market',
                time_in_force='gtc'
            )
            print(f"Submitted sell order for {row['Quantity']} {symbol} at {row['Price']}")
        except tradeapi.rest.APIError as e:
            print(f'Error when submitting sell order for {symbol}: {str(e)}')
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[6], line 85
#      83 if row['Order'] == 'Buy':
#      84     try:
# ---> 85         api.submit_order(
#      86             symbol=symbol,
#      87             qty=row['Quantity'],
#      88             side='buy',
#      89             type='market',
#      90             time_in_force='gtc'
#      91         )
#      92         print(f"Submitted buy order for {row['Quantity']} {symbol} at {row['Price']}")
#      93     except tradeapi.rest.APIError as e:
#
# File ~\AppData\Local\anaconda3\lib\site-packages\alpaca_trade_api\rest.py:429, in REST.submit_order(self, symbol, qty, side, type, time_in_force, limit_price, stop_price, client_order_id, extended_hours, order_class, take_profit, stop_loss, trail_price, trail_percent, notional)
# ...

# %%
import alpaca_trade_api as tradeapi
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd

# Define your keys
BASE_URL = "https://paper-api.alpaca.markets"
ALPACA_API_KEY = "PKSZXS4Q79O1VIXILWAS"
ALPACA_SECRET_KEY = "Ekki5szEyl4MtqHZzh788ZF8kIi43DEEmxmT8k6S"

# Instantiate REST API Connection
api = tradeapi.REST(key_id=ALPACA_API_KEY, secret_key=ALPACA_SECRET_KEY, base_url=BASE_URL)

# Define the date range for backtesting (last 4 months)
end_date = datetime.now()
start_date = end_date - timedelta(days=4 * 30)

# Fetch daily data for Apple stock
symbol = 'AAPL'
stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1d')

# Existing code for calculating pivot points, support/resistance, etc.
pivot_point = (stock_data['High'] + stock_data['Low'] + stock_data['Close']) / 3

# Calculate support and resistance levels
first_support = (2 * pivot_point) - stock_data['High']
first_resistance = (2 * pivot_point) - stock_data['Low']
second_support = pivot_point - (stock_data['High'] - stock_data['Low'])
second_resistance = pivot_point + (stock_data['High'] - stock_data['Low'])
third_support = pivot_point - 2 * (stock_data['High'] - stock_data['Low'])
third_resistance = pivot_point + 2 * (stock_data['High'] - stock_data['Low'])

# Create a new DataFrame to store the pivot points and support/resistance levels
pivot_df = pd.DataFrame(index=stock_data.index)
pivot_df['Pivot'] = pivot_point
pivot_df['Support 1'] = first_support
pivot_df['Resistance 1'] = first_resistance
pivot_df['Support 2'] = second_support
pivot_df['Resistance 2'] = second_resistance
pivot_df['Support 3'] = third_support
pivot_df['Resistance 3'] = third_resistance

# Merge the pivot DataFrame with the stock data DataFrame
stock_data_with_pivot = pd.concat([stock_data, pivot_df], axis=1)

# Create signals based on pivot points
stock_data_with_pivot['Signal'] = 0
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 1'], 'Signal'] = 1
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 2'], 'Signal'] = 2
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 3'], 'Signal'] = 3
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 1'], 'Signal'] = -1
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 2'], 'Signal'] = -2
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 3'], 'Signal'] = -3

# Generate trading orders based on the signals
backtest_results = pd.DataFrame(index=stock_data_with_pivot.index, columns=['Order', 'Price', 'Quantity'])
for index, row in stock_data_with_pivot.iterrows():
    if row['Signal'] > 0:
        backtest_results.loc[index, 'Order'] = 'Buy'
        backtest_results.loc[index, 'Price'] = stock_data_with_pivot.loc[index, 'Close']
        backtest_results.loc[index, 'Quantity'] = 100
    elif row['Signal'] < 0:
        backtest_results.loc[index, 'Order'] = 'Sell'
        backtest_results.loc[index, 'Price'] = stock_data_with_pivot.loc[index, 'Close']
        backtest_results.loc[index, 'Quantity'] = 100

# Implement the day trading rule
day_trades = 0
for index, row in backtest_results.iterrows():
    if row['Order'] != 'Hold':
        day_trades += 1
    if day_trades > 3:
        row['Order'] = 'Hold'

# Execute the trading orders
for index, row in backtest_results.iterrows():
    symbol = 'AAPL'
    if row['Order'] == 'Buy':
        try:
            api.submit_order(
                symbol=symbol,
                qty=row['Quantity'],
                side='buy',
                type='market',
                time_in_force='gtc'
            )
            print(f"Submitted buy order for {row['Quantity']} {symbol} at {row['Price']}")
        except tradeapi.rest.APIError as e:
            print(f'Error when submitting buy order for {symbol}: {str(e)}')
    elif row['Order'] == 'Sell':
        try:
            api.submit_order(
                symbol=symbol
# Out:
#   Cell In[5], line 93
#     symbol=symbol
#                  ^
# SyntaxError: incomplete input

# %%
import alpaca_trade_api as tradeapi
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd

# Define your keys
BASE_URL = "https://paper-api.alpaca.markets"
ALPACA_API_KEY = "PK7IMALR7RRU0CQF152H"
ALPACA_SECRET_KEY = "ZsbaBgBPA3ZKhZWYrbVpvFlQpDVlcfxYfWNtCfyF"

# Instantiate REST API Connection
api = tradeapi.REST(key_id=ALPACA_API_KEY, secret_key=ALPACA_SECRET_KEY, base_url=BASE_URL)

# Define the date range for backtesting (last 4 months)
end_date = datetime.now()
start_date = end_date - timedelta(days=4 * 30)

# Fetch daily data for Apple stock
symbol = 'AAPL'
stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1d')

# Existing code for calculating pivot points, support/resistance, etc.
pivot_point = (stock_data['High'] + stock_data['Low'] + stock_data['Close']) / 3

# Calculate support and resistance levels
first_support = (2 * pivot_point) - stock_data['High']
first_resistance = (2 * pivot_point) - stock_data['Low']
second_support = pivot_point - (stock_data['High'] - stock_data['Low'])
second_resistance = pivot_point + (stock_data['High'] - stock_data['Low'])
third_support = pivot_point - 2 * (stock_data['High'] - stock_data['Low'])
third_resistance = pivot_point + 2 * (stock_data['High'] - stock_data['Low'])

# Create a new DataFrame to store the pivot points and support/resistance levels
pivot_df = pd.DataFrame(index=stock_data.index)
pivot_df['Pivot'] = pivot_point
pivot_df['Support 1'] = first_support
pivot_df['Resistance 1'] = first_resistance
pivot_df['Support 2'] = second_support
pivot_df['Resistance 2'] = second_resistance
pivot_df['Support 3'] = third_support
pivot_df['Resistance 3'] = third_resistance

# Merge the pivot DataFrame with the stock data DataFrame
stock_data_with_pivot = pd.concat([stock_data, pivot_df], axis=1)

# Create signals based on pivot points
stock_data_with_pivot['Signal'] = 0
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 1'], 'Signal'] = 1
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 2'], 'Signal'] = 2
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 3'], 'Signal'] = 3
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 1'], 'Signal'] = -1
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 2'], 'Signal'] = -2
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 3'], 'Signal'] = -3

# Generate trading orders based on the signals
backtest_results = pd.DataFrame(index=stock_data_with_pivot.index, columns=['Order', 'Price', 'Quantity'])
for index, row in stock_data_with_pivot.iterrows():
    if row['Signal'] > 0:
        backtest_results.loc[index, 'Order'] = 'Buy'
        backtest_results.loc[index, 'Price'] = stock_data_with_pivot.loc[index, 'Close']
        backtest_results.loc[index, 'Quantity'] = 100
    elif row['Signal'] < 0:
        backtest_results.loc[index, 'Order'] = 'Sell'
        backtest_results.loc[index, 'Price'] = stock_data_with_pivot.loc[index, 'Close']
        backtest_results.loc[index, 'Quantity'] = 100
# Execute the trading orders
for index, row in backtest_results.iterrows():
    symbol = 'AAPL'
    if row['Order'] == 'Buy':
        try:
            api.submit_order(
                symbol=symbol,
                qty=row['Quantity'],
                side='buy',
                type='market',
                time_in_force='gtc'
            )
            print(f"Submitted buy order for {row['Quantity']} {symbol} at {row['Price']}")
        except tradeapi.rest.APIError as e:
            print(f'Error when submitting buy order for {symbol}: {str(e)}')
    elif row['Order'] == 'Sell':
        try:
            api.submit_order(
                symbol=symbol,
                qty=row['Quantity'],
                side='sell',
                type='market',
                time_in_force='gtc'
            )
            print(f"Submitted sell order for {row['Quantity']} {symbol} at {row['Price']}")
        except tradeapi.rest.APIError as e:
            print(f'Error when submitting sell order for {symbol}: {str(e)}')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Submitted buy order for 100 AAPL at 152.99000549316406
# Submitted buy order for 100 AAPL at 155.85000610351562
# Submitted sell order for 100 AAPL at 155.0
# Submitted buy order for 100 AAPL at 157.39999389648438
# Submitted buy order for 100 AAPL at 159.27999877929688
# Submitted sell order for 100 AAPL at 157.8300018310547
# Submitted sell order for 100 AAPL at 158.92999267578125
# Submitted buy order for 100 AAPL at 160.25
# Submitted sell order for 100 AAPL at 158.27999877929688
# Submitted buy order for 100 AAPL at 157.64999389648438
# Submitted buy order for 100 AAPL at 160.77000427246094
# Submitted buy order for 100 AAPL at 162.36000061035156
# Submitted buy order for 100 AAPL at 164.89999389648438
# Submitted buy order for 100 AAPL at 166.1699981689453
# Submitted sell order for 100 AAPL at 165.6300048828125
# Submitted buy order for 100 AAPL at 163.75999450683594
# ...

# %%
import alpaca_trade_api as tradeapi
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd
import time

# Define your keys
BASE_URL = "https://paper-api.alpaca.markets"
ALPACA_API_KEY = "PK7IMALR7RRU0CQF152H"
ALPACA_SECRET_KEY = "ZsbaBgBPA3ZKhZWYrbVpvFlQpDVlcfxYfWNtCfyF"

# Instantiate REST API Connection
api = tradeapi.REST(key_id=ALPACA_API_KEY, secret_key=ALPACA_SECRET_KEY, base_url=BASE_URL)

# Define the date range for backtesting (last 4 months)
end_date = datetime.now()
start_date = end_date - timedelta(days=4 * 30)

while True:
    # Fetch daily data for Apple stock
    symbol = 'AAPL'
    stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1d')

    # Existing code for calculating pivot points, support/resistance, etc.
    pivot_point = (stock_data['High'] + stock_data['Low'] + stock_data['Close']) / 3

    # Calculate support and resistance levels
    first_support = (2 * pivot_point) - stock_data['High']
    first_resistance = (2 * pivot_point) - stock_data['Low']
    second_support = pivot_point - (stock_data['High'] - stock_data['Low'])
    second_resistance = pivot_point + (stock_data['High'] - stock_data['Low'])
    third_support = pivot_point - 2 * (stock_data['High'] - stock_data['Low'])
    third_resistance = pivot_point + 2 * (stock_data['High'] - stock_data['Low'])

    # Create a new DataFrame to store the pivot points and support/resistance levels
    pivot_df = pd.DataFrame(index=stock_data.index)
    pivot_df['Pivot'] = pivot_point
    pivot_df['Support 1'] = first_support
    pivot_df['Resistance 1'] = first_resistance
    pivot_df['Support 2'] = second_support
    pivot_df['Resistance 2'] = second_resistance
    pivot_df['Support 3'] = third_support
    pivot_df['Resistance 3'] = third_resistance

    # Merge the pivot DataFrame with the stock data DataFrame
    stock_data_with_pivot = pd.concat([stock_data, pivot_df], axis=1)

    # Create signals based on pivot points
    stock_data_with_pivot['Signal'] = 0
    stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 1'], 'Signal'] = 1
    stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 2'], 'Signal'] = 2
    stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 3'], 'Signal'] = 3
    stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 1'], 'Signal'] = -1
    stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 2'], 'Signal'] = -2
    stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 3'], 'Signal'] = -3

    # Generate trading orders based on the signals
    backtest_results = pd.DataFrame(index=stock_data_with_pivot.index, columns=['Order', 'Price', 'Quantity'])
    for index, row in stock_data_with_pivot.iterrows():
        if row['Signal'] > 0:
            backtest_results.loc[index, 'Order'] = 'Buy'
            backtest_results.loc[index, 'Price'] = stock_data_with_pivot.loc[index, 'Close']
            backtest_results.loc[index, 'Quantity'] = 100
        elif row['Signal'] < 0:
            backtest_results.loc[index, 'Order'] = 'Sell'
            backtest_results.loc[index, 'Price'] = stock_data_with_pivot.loc[index, 'Close']
            backtest_results.loc[index, 'Quantity'] = 100

    # Execute the trading orders
    for index, row in backtest_results.iterrows():
        symbol = 'AAPL'
        if row['Order'] == 'Buy':
            try:
                api.submit_order(
                    symbol=symbol,
                    qty=row['Quantity'],
                    side='buy',
                    type='market',
                    time_in_force='gtc'
                )
                print(f"Submitted buy order for {row['Quantity']} {symbol} at {row['Price']}")
            except tradeapi.rest.APIError as e:
                print(f'Error when submitting buy order for {symbol}: {str(e)}')
        elif row['Order'] == 'Sell':
            try:
                api.submit_order(
                    symbol=symbol,
                    qty=row['Quantity'],
                    side='sell',
                    type='market',
                    time_in_force='gtc'
                )
                print(f"Submitted sell order for {row['Quantity']} {symbol} at {row['Price']}")
            except tradeapi.rest.APIError as e:
                print(f'Error when submitting sell order for {symbol}: {str(e)}')

    # Sleep for a specified interval before checking for new signals
    time.sleep(1800)  # Sleep for 60 seconds (adjust as needed)

# %%
import alpaca_trade_api as tradeapi
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd
# Define your keys
BASE_URL = "https://paper-api.alpaca.markets"
ALPACA_API_KEY = "PKSZXS4Q79O1VIXILWAS"
ALPACA_SECRET_KEY = "Ekki5szEyl4MtqHZzh788ZF8kIi43DEEmxmT8k6S"
# Instantiate REST API Connection
api = tradeapi.REST(key_id=ALPACA_API_KEY, secret_key=ALPACA_SECRET_KEY, base_url=BASE_URL)
# Define the date range for backtesting (last 4 months)
end_date = datetime.now()
start_date = end_date - timedelta(days=4 * 30)
# Fetch daily data for Apple stock
symbol = 'AAPL'
stock_data = yf.download(symbol, start=start_date, end=end_date, interval='1h')
# Existing code for calculating pivot points, support/resistance, etc.
pivot_point = (stock_data['High'] + stock_data['Low'] + stock_data['Close']) / 3
# Calculate support and resistance levels
first_support = (2 * pivot_point) - stock_data['High']
first_resistance = (2 * pivot_point) - stock_data['Low']
second_support = pivot_point - (stock_data['High'] - stock_data['Low'])
second_resistance = pivot_point + (stock_data['High'] - stock_data['Low'])
third_support = pivot_point - 2 * (stock_data['High'] - stock_data['Low'])
third_resistance = pivot_point + 2 * (stock_data['High'] - stock_data['Low'])
# Create a new DataFrame to store the pivot points and support/resistance levels
pivot_df = pd.DataFrame(index=stock_data.index)
pivot_df['Pivot'] = pivot_point
pivot_df['Support 1'] = first_support
pivot_df['Resistance 1'] = first_resistance
pivot_df['Support 2'] = second_support
pivot_df['Resistance 2'] = second_resistance
pivot_df['Support 3'] = third_support
pivot_df['Resistance 3'] = third_resistance
# Merge the pivot DataFrame with the stock data DataFrame
stock_data_with_pivot = pd.concat([stock_data, pivot_df], axis=1)
# Create signals based on pivot points
stock_data_with_pivot['Signal'] = 0
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 1'], 'Signal'] = 1
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 2'], 'Signal'] = 2
stock_data_with_pivot.loc[stock_data_with_pivot['Low'] < stock_data_with_pivot['Support 3'], 'Signal'] = 3
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 1'], 'Signal'] = -1
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 2'], 'Signal'] = -2
stock_data_with_pivot.loc[stock_data_with_pivot['High'] > stock_data_with_pivot['Resistance 3'], 'Signal'] = -3
# Generate trading orders based on the signals
backtest_results = pd.DataFrame(index=stock_data_with_pivot.index, columns=['Order', 'Price', 'Quantity'])
for index, row in stock_data_with_pivot.iterrows():
    if row['Signal'] > 0:
        backtest_results.loc[index, 'Order'] = 'Buy'
        backtest_results.loc[index, 'Price'] = stock_data_with_pivot.loc[index, 'Close']
        backtest_results.loc[index, 'Quantity'] = 100
    elif row['Signal'] < 0:
        backtest_results.loc[index, 'Order'] = 'Sell'
        backtest_results.loc[index, 'Price'] = stock_data_with_pivot.loc[index, 'Close']
        backtest_results.loc[index, 'Quantity'] = 100
# Calculate the portfolio value
backtest_results['Portfolio Value'] = 0
cash = 100000  # Initial capital
shares = 0
for index, row in backtest_results.iterrows():
    if row['Order'] == 'Buy':
        shares += row['Quantity']
        cash -= row['Price'] * row['Quantity']
    elif row['Order'] == 'Sell':
        shares -= row['Quantity']
        cash += row['Price'] * row['Quantity']
    backtest_results.loc[index, 'Portfolio Value'] = cash + (shares * row['Price'])
# Print the backtest results
pd.set_option('display.max_rows', None)
backtest_results
